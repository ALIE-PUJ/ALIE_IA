# %% [markdown]
# # ALIE
# ### Testing with the following questions:

# %%
alie_questions = [
    {
        "pregunta": "Hay algun estudiante llamado Luis? Quien?",
        "funcionalidad": "get_students_by_name"
    },
    {
        "pregunta": "Cual es el codigo de la materia llamada 'Estructuras de datos'?",
        "funcionalidad": "get_course_by_name"
    },
    {
        "pregunta": "Cual es el curso con codigo 4196?",
        "funcionalidad": "get_course_by_name"
    },
    {
        "pregunta": "Cuentame sobre el curso con codigo 3194",
        "funcionalidad": "get_course_by_name"
    },
    {
        "pregunta": "Cuales son las clases disponibles para la materia con codigo 4196?",
        "funcionalidad": "get_classes_by_course_code"
    },
    {
        "pregunta": "Cuales son las clases disponibles para la materia Estructuras de datos? Dame sus codigos",
        "funcionalidad": "get_classes_by_course_name"
    },
    {
        "pregunta": "Cuentame sobre las clases  disponibles para arquitectura de software",
        "funcionalidad": "get_classes_by_course_name"
    },
    {
        "pregunta": "Que informacion me puedes dar sobre la clase 1557?",
        "funcionalidad": "get_class_by_code"
    },
    {
        "pregunta": "Cuales son los prerrequisitos para Estructuras de datos?",
        "funcionalidad": "get_prerequisites_by_course_name"
    },
    {
        "pregunta": "Cuales son los prerrequisitos para Arquitectura de software?",
        "funcionalidad": "get_prerequisites_by_course_name"
    },
    {
        "pregunta": "Cuales son los prerrequisitos para Introduccion a la programacion?",
        "funcionalidad": "get_prerequisites_by_course_name"
    },
    {
        "pregunta": "Cuales son los prerrequisitos para la materia con codigo 4196?",
        "funcionalidad": "get_prerequisites_by_course_code"
    },
    {
        "pregunta": "Cuales son los prerrequisitos para el curso con ID 3194?",
        "funcionalidad": "get_prerequisites_by_course_code"
    },
    {
        "pregunta": "Cuales son los horarios disponibles para la clase 1557?",
        "funcionalidad": "get_class_schedule"
    },
    {
        "pregunta": "Hay algun profesor llamado Oscar? Quien?",
        "funcionalidad": "get_teacher_by_name"
    },
    {
        "pregunta": "Hay algun profesor llamado Carlos? Si lo hay, cuéntame!",
        "funcionalidad": "get_teacher_by_name"
    },
    {
        "pregunta": "Cuales son mis notas? Mi ID de estudiante es 200",
        "funcionalidad": "get_student_grades_by_period"
    },
    {
        "pregunta": "Que cursos he cursado? Mi ID de estudiante es 200",
        "funcionalidad": "get_student_courses"
    },
    {
        "pregunta": "Cuales son todos los cursos disponibles en Ingenieria de Sistemas?",
        "funcionalidad": "get_all_courses"
    },
    {
        "pregunta": "En que clases estoy inscrito? Mi ID de estudiante es 200",
        "funcionalidad": "get_student_classes"
    },
    {
        "pregunta": "Cuales becas estan disponibles para los estudiantes?",
        "funcionalidad": "general_retrieval"
    },
    {
        "pregunta": "Aparte de las becas, hay alguna opcion de financiacion disponible?",
        "funcionalidad": "general_retrieval"
    },
    {
        "pregunta": "Cuales son las enfasis de carrera para ingenieria de sistemas?",
        "funcionalidad": "general_retrieval"
    },
    {
        "pregunta": "Cuales son los semilleros disponibles?",
        "funcionalidad": "general_retrieval"
    },
    {
        "pregunta": "¿Que me puedes decir sobre el Saber Pro?",
        "funcionalidad": "general_retrieval"
    },
    {
        "pregunta": "¿La carrera ofrece consejerías?",
        "funcionalidad": "general_retrieval"
    },
    {
        "pregunta": "¿Como funcionan los intersemestrales?",
        "funcionalidad": "general_retrieval"
    },
    {
        "pregunta": "Me enfermé y falté a unas clases. ¿Cómo puedo enviar una excusa?",
        "funcionalidad": "general_retrieval"
    },
    {
        "pregunta": "Estoy por graduarme. ¿Puedes contarme sobre cómo es el proceso?",
        "funcionalidad": "general_retrieval"
    },
    {
        "pregunta": "Estoy planeando qué asignaturas inscribir. ¿Donde puedo encontrar el plan de estudios de ingenieria de sistemas?",
        "funcionalidad": "general_retrieval"
    },
    {
        "pregunta": "¿Hay posibilidades de intercambio en la universidad?",
        "funcionalidad": "general_retrieval"
    },
    {
        "pregunta": "¿Cuales son los contenidos de estructuras de datos?",
        "funcionalidad": "course_retrieval"
    },
    {
        "pregunta": "¿Cuales son los resultados esperados de aprendizaje para introduccion a la programación?",
        "funcionalidad": "course_retrieval"
    },
    {
        "pregunta": "¿Como se evalua programación avanzada?",
        "funcionalidad": "course_retrieval"
    },
    {
        "pregunta": "¿En qué tipo de consultas puedes ayudar?",
        "funcionalidad": "normal_conversation"
    }
]


print(f"Hay {len(alie_questions)} preguntas indexadas")
# Out:
# Hay 35 preguntas indexadas

# %%
import random

# Triplicar la lista
alie_questions *= 3
print(f"Hay {len(alie_questions)} preguntas indexadas")

# Borrar 5 preguntas aleatorias
for _ in range(5):
    alie_questions.pop(random.randint(0, len(alie_questions) - 1))

print(f"Hay {len(alie_questions)} preguntas después de borrar 5 aleatorias")
# Out:
# Hay 105 preguntas indexadas
# Hay 100 preguntas después de borrar 5 aleatorias

# %% [markdown]
# ## Request and supervision

# %%
# Dependencies
# !pip install requests pandas
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Users\Luis Alejandro\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Authorization Header

# %%
import requests

# Datos de autenticación
BASE_URL = 'http://localhost:2001/api/auth'  # La URL de la API de autenticación
USERNAME = "luis.bravo@javeriana.edu.com"
PASSWORD = "123456"

def login_and_get_header():
    """
    Inicia sesión, obtiene el token de autenticación, y devuelve un encabezado de autorización.
    
    :return: dict - encabezado con el token de autorización y 'accept': 'application/json'
    """
    # Definir payload para iniciar sesión
    payload = {
        "email": USERNAME,
        "contrasena": PASSWORD
    }

    # Hacer la solicitud POST al endpoint /login
    response = requests.post(f'{BASE_URL}/login', json=payload)

    # Verificar que la solicitud fue exitosa
    if response.status_code == 200:
        # Extraer token de la respuesta
        response_data = response.json()
        token = response_data['token']
        print(f"Token obtenido: {token}")

        # Crear el header con el token y el campo 'accept'
        headers = {
            'Authorization': f'Bearer {token}',
            'accept': 'application/json'
        }

        # Retornar el header para usarlo en otras solicitudes
        return headers
    else:
        # Si falla el login, imprimir el error y devolver None
        print(f"Error al iniciar sesión: {response.status_code} - {response.text}")
        return None

# Ejemplo de uso
if __name__ == '__main__':

    '''
    headers = login_and_get_header()
    if headers:
        print("Header de autorización creado con éxito:", headers)
        # Ahora puedes usar 'headers' en otras solicitudes de la API
    else:
        print("No se pudo crear el header de autorización.")
    '''

# %%
auth_headers = login_and_get_header() # Get the auth header

print("auth_headers: ", auth_headers)
# Out:
# Token obtenido: eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJpZF91c3VhcmlvIjoxLCJ1c3VhcmlvIjoiTHVpcyBCcmF2byIsImVtYWlsIjoibHVpcy5icmF2b0BqYXZlcmlhbmEuZWR1LmNvbSIsImlkX2NhdGVnb3JpYSI6MiwiaWF0IjoxNzI4MTk0NTI0LCJleHAiOjE3MjgxOTgxMjR9.mfQBSNC50ZlvKVgPgZXFOI80EBoPj4dRjZP0AtlsViVHipdUcqKOp40XXy4_tupmfDoU9MUS4b5baeyl744Dzg
# auth_headers:  {'Authorization': 'Bearer eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJpZF91c3VhcmlvIjoxLCJ1c3VhcmlvIjoiTHVpcyBCcmF2byIsImVtYWlsIjoibHVpcy5icmF2b0BqYXZlcmlhbmEuZWR1LmNvbSIsImlkX2NhdGVnb3JpYSI6MiwiaWF0IjoxNzI4MTk0NTI0LCJleHAiOjE3MjgxOTgxMjR9.mfQBSNC50ZlvKVgPgZXFOI80EBoPj4dRjZP0AtlsViVHipdUcqKOp40XXy4_tupmfDoU9MUS4b5baeyl744Dzg', 'accept': 'application/json'}

# %% [markdown]
# Process Requests

# %%
import requests
import pandas as pd
import random
import time

# Mezclar preguntas
random.shuffle(alie_questions)

# Inicializar lista de respuestas
responses = []

# Función para hacer la solicitud y almacenar la respuesta
def get_response(pregunta):
    start_time = time.time()
    response = requests.post(
        "http://localhost:3000/api/ia/chat",
        json={"input": pregunta, "priority": "False"},
        #headers={'Content-Type': 'application/json; charset=utf-8'}
        headers=auth_headers
    )
    end_time = time.time()
    response_time = end_time - start_time
    
    # Decodificar la respuesta
    response_data = response.json()
    answer = response_data.get("answer", "No se recibió respuesta")
    
    return answer, response_time


# Si se quiere hacer con una sola pregunta
alie_questions = alie_questions[:1]


# Obtener respuestas para todas las preguntas
for item in alie_questions:
    pregunta = item["pregunta"]
    respuesta, tiempo = get_response(pregunta)
    responses.append({
        "Pregunta": pregunta,
        "Respuesta": respuesta,
        "Supervisión": None,
        "Tiempo de Respuesta (s)": round(tiempo, 2)
    })

# %%
# Convertir a DataFrame
df_responses = pd.DataFrame(responses)

# Mostrar el DataFrame
display(df_responses)
# Out:
#                                             Pregunta  \
# 0  Cuales son todos los cursos disponibles en Ing...
#
#                                            Respuesta Supervisión  \
# 0  La información sobre los cursos disponibles en...        None
#
#    Tiempo de Respuesta (s)
# 0                    12.74

# %%
import pandas as pd
from flask import Flask, render_template_string, request

# Crear una aplicación Flask
app = Flask(__name__)

@app.route('/', methods=['GET', 'POST'])
def home():
    global df_responses
    if request.method == 'POST':
        evaluations = []
        for idx in range(len(df_responses)):
            evaluation = request.form.get(f'evaluation{idx}')
            evaluations.append(evaluation)

        if None in evaluations:
            return "Error: No todas las respuestas fueron evaluadas.", 400

        correct_count = evaluations.count('correct')
        total_count = len(evaluations)
        effectiveness = (correct_count / total_count) * 100 if total_count > 0 else 0
        fallback = (total_count - correct_count) / total_count * 100 if total_count > 0 else 0
        df_responses['Supervisión'] = evaluations

        table_html = df_responses.to_html(classes='table table-striped', index=False, escape=False)

        html = f'''
        <html>
        <head>
            <title>Evaluación de Respuestas</title>
            <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
            <style>
                .table-container {{
                    max-height: auto;
                    overflow-y: auto;
                    overflow-x: hidden;
                }}
                .table {{
                    width: 100%;
                    table-layout: auto;
                }}
                th, td {{
                    overflow: hidden;
                    text-overflow: ellipsis;
                    word-wrap: break-word;
                }}
                td {{
                    max-width: 300px;
                }}
            </style>
        </head>
        <body>
            <div class="container">
                <h1 style="margin-top: 20px;">Evaluación de Respuestas</h1>
                <div class="table-container">
                    {table_html}
                </div>
                <h2>Resultados de Evaluación</h2>
                <p>Cantidad de Preguntas: {len(alie_questions)}</p>
                <p>Índice de Efectividad: {effectiveness:.2f}%</p>
                <p>Índice de Fallback: {fallback:.2f}%</p>
                <a href="/">Volver a evaluar</a>
            </div>
        </body>
        </html>
        '''
        return render_template_string(html)

    table_html = df_responses.to_html(classes='table table-striped', index=False, escape=False)

    evaluation_inputs = ''.join(
        f'''
        <tr>
            <td>{idx + 1}</td>
            <td>{row['Pregunta']}</td>
            <td>{row['Respuesta']}</td>
            <td>
                <input type="radio" name="evaluation{idx}" value="correct" required> Correcto
                <input type="radio" name="evaluation{idx}" value="incorrect"> Incorrecto
            </td>
            <td>{row['Tiempo de Respuesta (s)']}</td>
        </tr>
        '''
        for idx, row in df_responses.iterrows()
    )

    html = f'''
    <html>
    <head>
        <title>Evaluación de Respuestas</title>
        <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
        <style>
            .table-container {{
                max-height: auto;
                overflow-y: auto;
                overflow-x: hidden;
            }}
            .table {{
                width: 100%;
                table-layout: auto;
            }}
            th, td {{
                overflow: hidden;
                text-overflow: ellipsis;
                word-wrap: break-word;
            }}
            td {{
                max-width: 300px;
            }}
        </style>
    </head>
    <body>
        <div class="container">
            <h1 style="margin-top: 20px;">Evaluación de Respuestas</h1>
            <form method="POST">
                <div class="table-container">
                    <table class="table table-striped">
                        <thead>
                            <tr>
                                <th>Número</th>
                                <th>Pregunta</th>
                                <th>Respuesta</th>
                                <th>Supervisión</th>
                                <th>Tiempo de Respuesta (s)</th>
                            </tr>
                        </thead>
                        <tbody>
                            {evaluation_inputs}
                        </tbody>
                    </table>
                </div>
                <button type="submit" class="btn btn-primary" style="margin-top: 8px;">Enviar Evaluación</button>
            </form>
        </div>
    </body>
    </html>
    '''
    return render_template_string(html)

if __name__ == '__main__':
    app.run(port=7000, debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:7000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Oct/2024 01:08:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Oct/2024 01:08:30] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Oct/2024 01:08:38] "POST / HTTP/1.1" 200 -
